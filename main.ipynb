# %%
import pandas as pd
import numpy as np

# %%
pip install -U openai-whisper
# Out:
# Requirement already satisfied: openai-whisper in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (20250625)
# Requirement already satisfied: more-itertools in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from openai-whisper) (11.1.0)
# Requirement already satisfied: numba in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from openai-whisper) (0.67.0)
# Requirement already satisfied: numpy in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from openai-whisper) (2.2.6)
# Requirement already satisfied: tiktoken in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from openai-whisper) (0.14.0)
# Requirement already satisfied: torch in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from openai-whisper) (2.6.0+cu124)
# Requirement already satisfied: tqdm in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from openai-whisper) (4.67.1)
# Requirement already satisfied: llvmlite<0.50,>=0.49.0dev0 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from numba->openai-whisper) (0.49.0)
# Requirement already satisfied: regex in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from tiktoken->openai-whisper) (2025.9.18)
# Requirement already satisfied: requests in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from tiktoken->openai-whisper) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from requests->tiktoken->openai-whisper) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from requests->tiktoken->openai-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from requests->tiktoken->openai-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from requests->tiktoken->openai-whisper) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: networkx in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (3.5)
# Requirement already satisfied: jinja2 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from torch->openai-whisper) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from sympy==1.13.1->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch->openai-whisper) (3.0.3)
# Requirement already satisfied: colorama in c:\users\andrei\appdata\local\programs\python\python313\lib\site-packages (from tqdm->openai-whisper) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset = pd.read_csv('comenzi.csv')
dataset.head()
# Out:
#    Id                Text         Command
# 0   0  deschide browserul    open_browser
# 1   1     porneste chrome    open_browser
# 2   2    deschide notepad    open_notepad
# 3   3   porneste editorul    open_notepad
# 4   4   opreste programul  exit_assistant

# %%
import whisper
model = whisper.load_model('medium')

# %%
request = model.transcribe('db.mp4', language='ro', fp16=False)
request
# Out:
# {'text': ' Deschide browserul',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 1.78,
#    'text': ' Deschide browserul',
#    'tokens': [50364, 3885, 339, 482, 11185, 425, 50453],
#    'temperature': 0.0,
#    'avg_logprob': -0.44937703013420105,
#    'compression_ratio': 0.6923076923076923,
#    'no_speech_prob': 0.11534394323825836}],
#  'language': 'ro'}
